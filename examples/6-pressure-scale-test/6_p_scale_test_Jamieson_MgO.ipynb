# %%
# %cat 0Source_Citation.txt
# Out:
# Source and citation
#
# - This notebook is a part of the `pytheos` package.
# - Website: http://github.com/SHDShim/pytheos.
# - How to cite: S.-H. Shim (2017) Pytheos - a python tool set for equations of state. DOI: 10.5281/zenodo.802392

# %%
# %matplotlib inline
# %matplotlib notebook # for interactive

# %% [markdown]
# For high dpi displays.

# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 0. General note

# %% [markdown]
# This example compares pressure calculated from `pytheos` and original publication for the MgO scale by Jamieson 1983.

# %% [markdown]
# # 1. Global setup

# %%
import matplotlib.pyplot as plt
import numpy as np
from uncertainties import unumpy as unp
import pytheos as eos

# %% [markdown]
# # 3. Compare

# %%
eta = np.linspace(0., 0.26, 53)
print(eta)
# Out:
# [0.    0.005 0.01  0.015 0.02  0.025 0.03  0.035 0.04  0.045 0.05  0.055
#  0.06  0.065 0.07  0.075 0.08  0.085 0.09  0.095 0.1   0.105 0.11  0.115
#  0.12  0.125 0.13  0.135 0.14  0.145 0.15  0.155 0.16  0.165 0.17  0.175
#  0.18  0.185 0.19  0.195 0.2   0.205 0.21  0.215 0.22  0.225 0.23  0.235
#  0.24  0.245 0.25  0.255 0.26 ]

# %%
jamieson_mgo = eos.periclase.Jamieson1982()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/pytheos-dev/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")

# %%
jamieson_mgo.print_equations()
# Out:
# P_static: Jamieson
# P_thermal: Constq
# P_anharmonic: None
# P_electronic: None

# %%
jamieson_mgo.print_parameters()
# Out:
# Static:  OrderedDict({'rho0': 3.585+/-0, 'c0': 6.597+/-0, 's': 1.369+/-0})
# Thermal:  OrderedDict({'v0': 74.67377022412799+/-0.001, 'gamma0': 1.32+/-0, 'q': 1.0+/-0, 'theta0': 760.0+/-0})
# Anharmonic: None
# Electronic: None

# %%
v0 = 74.67451012663052

# %%
jamieson_mgo.three_r
# Out:
# 24.938906080000002

# %%
v = v0 * (1.-eta) 
temp = 1500.

# %%
p = jamieson_mgo.cal_p(v, temp * np.ones_like(v))

# %% [markdown]
# <img src='./tables/Jamieson_MgO_1.png'>
# <img src='./tables/Jamieson_MgO_2.png'>

# %%
print('for T = ', temp)
for eta_i, p_i in zip(eta, p):
    print("{0: .3f} {1: .2f}".format(eta_i, p_i))
# Out:
# for T =  1500.0
#  0.000  6.61+/-0.00
#  0.005  7.39+/-0.00
#  0.010  8.19+/-0.00
#  0.015  9.01+/-0.00
#  0.020  9.86+/-0.00
#  0.025  10.72+/-0.00
#  0.030  11.62+/-0.00
#  0.035  12.54+/-0.00
#  0.040  13.48+/-0.00
#  0.045  14.45+/-0.00
#  0.050  15.45+/-0.00
#  0.055  16.47+/-0.00
#  0.060  17.53+/-0.00
#  0.065  18.62+/-0.00
#  0.070  19.73+/-0.00
#  0.075  20.88+/-0.00
#  0.080  22.06+/-0.00
#  0.085  23.28+/-0.00
#  0.090  24.53+/-0.00
#  0.095  25.81+/-0.00
#  0.100  27.13+/-0.00
#  0.105  28.49+/-0.00
#  0.110  29.89+/-0.00
#  0.115  31.33+/-0.00
#  0.120  32.82+/-0.00
#  0.125  34.34+/-0.00
#  0.130  35.91+/-0.00
#  0.135  37.53+/-0.00
#  0.140  39.19+/-0.00
#  0.145  40.91+/-0.00
#  0.150  42.67+/-0.00
#  0.155  44.49+/-0.00
#  0.160  46.36+/-0.00
#  0.165  48.29+/-0.00
#  0.170  50.28+/-0.00
#  0.175  52.32+/-0.00
#  0.180  54.43+/-0.00
#  0.185  56.61+/-0.00
#  0.190  58.85+/-0.00
#  0.195  61.16+/-0.00
#  0.200  63.54+/-0.00
#  0.205  66.00+/-0.00
#  0.210  68.53+/-0.00
#  0.215  71.15+/-0.00
#  0.220  73.85+/-0.00
#  0.225  76.63+/-0.00
#  0.230  79.51+/-0.00
#  0.235  82.48+/-0.00
#  0.240  85.54+/-0.00
#  0.245  88.71+/-0.00
#  0.250  91.98+/-0.00
#  0.255  95.36+/-0.00
#  0.260  98.85+/-0.00

# %%
p = np.linspace(0, 10, 11)
temp = 2000

for pi in p:
    v = jamieson_mgo.cal_v(pi, temp)
    print(1- (v/v0), v, pi)
# Out:
# -0.07620473939681482 80.36506171041522 0.0
# -0.06648157767852259 79.63898937221973 1.0
# -0.05726429677047573 78.95069343571178 2.0
# -0.048501155911436555 78.29631018489238 3.0
# -0.040148243987024435 77.67256057880601 4.0
# -0.03216794746696161 77.07663584550507 5.0
# -0.024527769917886078 76.50610932974737 6.0
# -0.01719942649240558 75.9588688744099 7.0
# -0.010158131598895226 75.43306362757987 8.0
# -0.003382032294423132 74.92706173144902 9.0
# 0.003148249730144159 74.43941612027571 10.0
